# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
train = pd.read_csv('/Users/willwolf/Documents/kaggle/liberty/data/train.csv', index_col=['Id'])

# %%
pd.read_sql_query(my_sql_engine, """SELECT * FROM temp_table WHERE month = '12'""")
# Out:
#         Hazard  T1_V1  T1_V2  T1_V3 T1_V4 T1_V5 T1_V6 T1_V7 T1_V8 T1_V9  \
# Id
# 1            1     15      3      2     N     B     N     B     B     D
# 2            4     16     14      5     H     B     N     B     B     C
# 3            1     10     10      5     N     K     N     B     B     E
# 4            1     18     18      5     N     K     N     B     B     E
# 5            1     13     19      5     N     H     N     B     B     E
# 12           1     14     12      2     N     K     N     B     B     E
# 15           5      8     17      1     E     K     N     B     B     E
# 19           1     14     20      4     E     K     N     B     B     E
# 21           1      8      2      2     W     C     N     D     B     D
# 22           1      5      4      3     B     I     N     D     B     F
# 23           7      4      7      5     N     C     Y     B     B     D
# 24          15     18     15      4     N     H     Y     B     B     E
# ...

# %%
train.describe()
# Out:
#              Hazard         T1_V1         T1_V2         T1_V3        T1_V10  \
# count  50999.000000  50999.000000  50999.000000  50999.000000  50999.000000
# mean       4.022785      9.722093     12.847585      3.186004      7.020451
# std        4.021194      5.167943      6.255743      1.739369      3.595279
# min        1.000000      1.000000      1.000000      1.000000      2.000000
# 25%        1.000000      6.000000      7.000000      2.000000      3.000000
# 50%        3.000000      9.000000     14.000000      3.000000      8.000000
# 75%        5.000000     14.000000     18.000000      4.000000      8.000000
# max       69.000000     19.000000     24.000000      9.000000     12.000000
#
#              T1_V13        T1_V14         T2_V1         T2_V2         T2_V4  \
# count  50999.000000  50999.000000  50999.000000  50999.000000  50999.000000
# mean      13.996255      1.578521     57.580051     12.419616     10.259495
# ...

# %%
train['T1_V1'].hist(bins=11, normed=True, log=True)

# %%
df = pd.DataFrame({
        'a': [1, 2],
        'b': [3, 4],
        'c': [5, 6],
        'd': [3, 5000]
    })

# %%
df['a'].hist()

# %%
df.describe()
# Out:
#               a         b         c            d
# count  2.000000  2.000000  2.000000     2.000000
# mean   1.500000  3.500000  5.500000  2501.500000
# std    0.707107  0.707107  0.707107  3533.412586
# min    1.000000  3.000000  5.000000     3.000000
# 25%    1.250000  3.250000  5.250000  1252.250000
# 50%    1.500000  3.500000  5.500000  2501.500000
# 75%    1.750000  3.750000  5.750000  3750.750000
# max    2.000000  4.000000  6.000000  5000.000000

# %%
df.max()
# Out:
# a       2
# b       4
# c       6
# d    5000
# dtype: int64

# %%
df['a']
# Out:
# 0    1
# 1    2
# Name: a, dtype: int64

# %%
df['d'].std()
# Out:
# 3533.412585589178

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
[1, 2].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-a64140a971bf> in <module>()
# ----> 1 [1, 2].max()
#
# AttributeError: 'list' object has no attribute 'max'

# %%
df['a']
# Out:
# 0    1
# 1    2
# Name: a, dtype: int64

# %%
df['a'].min()
# Out:
# 1

# %%
random_vals = pd.Series(np.random.randint(0, 10, (1000,)))

# %%
type(random_vals)
# Out:
# pandas.core.series.Series

# %%
random_vals.hist()

# %%
random_vals.value_counts()
# Out:
# 1    109
# 7    105
# 9    100
# 6    100
# 5     99
# 3     99
# 2     98
# 0     98
# 8     96
# 4     96
# dtype: int64

# %%
random_vals
# Out:
# 0      9
# 1      4
# 2      9
# 3      3
# 4      5
# 5      0
# 6      5
# 7      1
# 8      8
# 9      2
# 10     6
# 11     9
# 12     6
# 13     1
# 14     7
# 15     9
# 16     8
# 17     9
# 18     1
# 19     8
# 20     3
# 21     3
# 22     3
# 23     0
# 24     8
# 25     1
# 26     7
# 27     0
# 28     3
# 29     6
#       ..
# 970    5
# 971    4
# 972    6
# 973    0
# 974    5
# 975    3
# 976    6
# 977    1
# 978    7
# 979    6
# 980    5
# 981    0
# 982    4
# 983    9
# 984    7
# 985    0
# 986    3
# 987    5
# 988    2
# 989    3
# 990    6
# 991    9
# 992    0
# 993    9
# 994    3
# 995    3
# 996    2
# 997    7
# 998    5
# 999    0
# dtype: int64

# %%
df['a'] + df['b']
# Out:
# 0    4
# 1    6
# dtype: int64
